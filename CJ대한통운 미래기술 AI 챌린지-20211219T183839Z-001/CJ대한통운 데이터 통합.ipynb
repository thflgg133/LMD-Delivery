# %%
import pandas as pd  
import numpy as np  
import glob  
import sys
i = 1

#파일 Union  
all_data = pd.DataFrame()  
for f in glob.glob('./drive/MyDrive/CJ대한통운 미래기술 AI 챌린지/택배 배송 데이터 CSV화/*.xlsx'): # 예를들어 201901, 201902 로 된 파일이면 2019_*  
  xlsx = pd.read_excel(f)  
  xlsx.to_csv("./drive/MyDrive/CJ대한통운 미래기술 AI 챌린지/택배 배송 데이터 CSV/2-%d. 택배 배송 데이터.csv"%i)
  i += 1
